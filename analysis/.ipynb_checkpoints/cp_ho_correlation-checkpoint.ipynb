# %%
# Description: Script to visualize the correlation between colonization pressure and Hospitalization Onset
# Dependencies: None
# Authors: Ziming (Alex) Wei
# Last updated: 2024-12-16

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
cp_correlation_df = pd.read_csv('/data/tide/projects/ho_infxn_ml/')
cp_correlation_df
# Out:
#        CDiff_cp   MSSA_cp   MRSA_cp  DS_Entero_cp    ESBL_cp    VSE_cp  \
# 0      0.988532  2.357932  1.370544     10.065712   4.818903  1.395731
# 1      1.442788  4.302232  6.718272     26.980571   9.469409  6.354509
# 2      3.256485  3.672115  3.203184      6.927528   4.587647  0.750444
# 3      0.787666  5.013287  2.323254     25.149141  15.261829  9.343341
# 4      3.135985  1.631565  3.801040     16.486518   3.567469  7.921504
# ...         ...       ...       ...           ...        ...       ...
# 30547  5.528103  4.544789  0.826081     10.500386   6.311030  1.199585
# 30548  0.816267  7.004767  3.732011     31.183321   9.590795  9.525334
# 30549  0.744521  6.829008  1.652598      3.710026   0.000000  0.000000
# 30550  0.000000  7.778490  5.585378     28.839274   5.230481  8.925034
# 30551  0.000000  0.706408  1.385957      8.613563   3.919841  0.779683
#
#          VRE_cp  DS_PsA_cp  DR_PsA_cp  group_binary      pred          run
# 0      1.774850   2.452820   0.000000             1  1.082297       C_diff
# 1      5.958006   2.910535   1.698250             0  0.923961       C_diff
# 2      1.453683   1.780369   0.000000             1  0.989050       C_diff
# 3      5.776471   3.052388   1.617717             0  1.011072       C_diff
# 4      1.404859   2.535518   1.861672             1  1.670962       C_diff
# ...         ...        ...        ...           ...       ...          ...
# 30547  2.417137   2.645681   0.000000             0  0.417173  VSE_faecium
# 30548  0.837565   7.587646   1.628332             1  2.689061  VSE_faecium
# 30549  0.000000   3.365889   0.000000             0  0.371877  VSE_faecium
# 30550  6.602927   4.226388   1.628471             1  2.280520  VSE_faecium
# 30551  0.934695   0.000000   0.419502             0  0.438496  VSE_faecium
#
# [30552 rows x 12 columns]

# %%
### C_Diff Correlation

cdiff_df = cp_correlation_df[cp_correlation_df['run'] == 'C_diff']

coefficients = np.polyfit(cdiff_df['CDiff_cp'], 
                          cdiff_df['pred'], 
                          1)
linear_fit = np.poly1d(coefficients)

plt.figure()
plt.scatter(x=cdiff_df['CDiff_cp'],
            y=cdiff_df['pred'],
           label = None)
plt.plot(cdiff_df['CDiff_cp'], 
         linear_fit(cdiff_df['CDiff_cp']), 
         color="red", 
         label=f"y={coefficients[0]:.2f}x + {coefficients[1]:.2f}")
plt.ylabel('Risk')
plt.xlabel('CDiff_cp')
plt.legend()
plt.show()
# Out:
# /opt/anaconda/3-5.2.0/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:2064: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /opt/anaconda/3-5.2.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:248: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]

# %%
### MRSA Correlation

mrsa_df = cp_correlation_df[cp_correlation_df['run'] == 'MRSA']

coefficients = np.polyfit(mrsa_df['MRSA_cp'], 
                          mrsa_df['pred'], 
                          1)
linear_fit = np.poly1d(coefficients)

plt.figure()
plt.scatter(x=mrsa_df['MRSA_cp'],
            y=mrsa_df['pred'],
           label = None)
plt.plot(mrsa_df['MRSA_cp'], 
         linear_fit(mrsa_df['MRSA_cp']), 
         color="red", 
         label=f"y={coefficients[0]:.2f}x + {coefficients[1]:.2f}")
plt.ylabel('Risk')
plt.xlabel('MRSA_cp')
plt.legend()
plt.show()
# Out:
# /opt/anaconda/3-5.2.0/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:2064: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /opt/anaconda/3-5.2.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:248: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]

# %%
### MSSA Correlation

mssa_df = cp_correlation_df[cp_correlation_df['run'] == 'MSSA']

coefficients = np.polyfit(mssa_df['MSSA_cp'], 
                          mssa_df['pred'], 
                          1)
linear_fit = np.poly1d(coefficients)

plt.figure()
plt.scatter(x=mssa_df['MSSA_cp'],
            y=mssa_df['pred'],
           label=None)
plt.plot(mssa_df['MSSA_cp'], 
         linear_fit(mssa_df['MSSA_cp']), 
         color="red", 
         label=f"y={coefficients[0]:.2f}x + {coefficients[1]:.2f}")
plt.ylabel('Risk')
plt.xlabel('MSSA_cp')
plt.legend()
plt.show()
# Out:
# /opt/anaconda/3-5.2.0/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:2064: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /opt/anaconda/3-5.2.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:248: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
