# %%
import pandas as pd
import numpy as np

# %%
old_coef = pd.read_csv('/data/tide/projects/ho_infxn_ml/results/model_results/20241210/clr_coefficients_removed_prior_pathogen.csv')
old_coef
# Out:
#              match       target      variable      coef  lower_CI  upper_CI  \
# 0    environmental       C_diff      CDiff_cp  1.379871  1.269233  1.500152
# 1    environmental       C_diff       MSSA_cp  0.956651  0.912444  1.002999
# 2    environmental       C_diff       MRSA_cp  0.975895  0.904679  1.052718
# 3    environmental       C_diff  DS_Entero_cp  0.965755  0.945742  0.986191
# 4    environmental       C_diff       ESBL_cp  1.007135  0.961827  1.054578
# ..             ...          ...           ...       ...       ...       ...
# 157  environmental  VSE_faecium       ESBL_cp  1.135975  0.962332  1.340951
# 158  environmental  VSE_faecium        VSE_cp  1.225244  1.044420  1.437374
# 159  environmental  VSE_faecium        VRE_cp  0.920575  0.735581  1.152094
# 160  environmental  VSE_faecium     DS_PsA_cp  0.903149  0.713441  1.143300
# 161  environmental  VSE_faecium     DR_PsA_cp  1.163143  0.854729  1.582842
#
#       SE_coef          pval sig_flag
# ...

# %%
new_coef = pd.read_csv('/data/tide/projects/ho_infxn_ml/results/model_results/20250205/clr/clr_coefficients.csv')
new_coef.columns = ['match','target','variable','elix5_coef','elix5_lower_CI','elix5_upper_CI','elix5_SE_coef','elix5_pval','elix5_sig_flag']
new_coef
# Out:
#              match        target      variable  elix5_coef  elix5_lower_CI  \
# 0    environmental        C_diff      CDiff_cp    1.311902        1.098581
# 1    environmental        C_diff       MSSA_cp    0.938909        0.838124
# 2    environmental        C_diff       MRSA_cp    1.001603        0.844804
# 3    environmental        C_diff  DS_Entero_cp    0.981050        0.940492
# 4    environmental        C_diff       ESBL_cp    1.088918        0.985029
# ..             ...           ...           ...         ...             ...
# 139  environmental  VSE_faecalis       ESBL_cp    1.016623        0.929078
# 140  environmental  VSE_faecalis        VSE_cp    1.093958        1.014896
# 141  environmental  VSE_faecalis        VRE_cp    1.131127        0.981223
# 142  environmental  VSE_faecalis     DS_PsA_cp    0.940075        0.827321
# 143  environmental  VSE_faecalis     DR_PsA_cp    0.883399        0.737743
#
#      elix5_upper_CI  elix5_SE_coef  elix5_pval elix5_sig_flag
# ...

# %%
combined_coef = old_coef.merge(new_coef,
                               on = ['match','target','variable'],
                               how = 'right')
combined_coef
# Out:
#              match        target      variable      coef  lower_CI  upper_CI  \
# 0    environmental        C_diff      CDiff_cp  1.379871  1.269233  1.500152
# 1    environmental        C_diff       MSSA_cp  0.956651  0.912444  1.002999
# 2    environmental        C_diff       MRSA_cp  0.975895  0.904679  1.052718
# 3    environmental        C_diff  DS_Entero_cp  0.965755  0.945742  0.986191
# 4    environmental        C_diff       ESBL_cp  1.007135  0.961827  1.054578
# ..             ...           ...           ...       ...       ...       ...
# 139  environmental  VSE_faecalis       ESBL_cp  0.993192  0.951155  1.037087
# 140  environmental  VSE_faecalis        VSE_cp  1.093004  1.046097  1.142015
# 141  environmental  VSE_faecalis        VRE_cp  1.034935  0.958463  1.117508
# 142  environmental  VSE_faecalis     DS_PsA_cp  1.007632  0.945289  1.074087
# 143  environmental  VSE_faecalis     DR_PsA_cp  0.899115  0.814870  0.992071
#
# ...

# %%
combined_coef.to_csv('/data/tide/projects/ho_infxn_ml/results/model_results/20241207/clr_coefficients_comparison.csv',
                    index = False)
